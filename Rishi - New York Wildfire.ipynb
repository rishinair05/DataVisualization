# %%
# !pip install geopandas

# %%
# Cleaning data
import folium
from folium import plugins
import pandas as pd
import geopandas as gpd

pd.set_option("display.max_rows", None, "display.max_columns", None)

df = pd.read_csv("https://raw.githubusercontent.com/justinabella/gecsummer2021/main/new-york-state-wildfire-2008-2019.csv")
df = df.drop(columns=["Complex Type", "State Land Unit Name", "Reporting Ranger", "Fire Report Method", "Railroad Name", "Location 1", "New York Zip Codes", "Counties", "NYS Municipal Boundaries"])
df['Year'] = df["Fire Start Date"]

df
df.head(103)
# Out:
#        Fire Number                 Incident Name          Fire Start Date  \
# 0    NYS-2019-0103            Tracy Creek Fire 2  2019-11-10T00:00:00.000
# 1    NYS-2019-0102     LIne Road East RX, Part 2  2019-10-26T00:00:00.000
# 2    NYS-2019-0101             Line Road East RX  2019-10-19T00:00:00.000
# 3    NYS-2019-0100              Randalls Rd Fire  2019-10-15T00:00:00.000
# 4    NYS-2019-0099             Yellowjacket Fire  2019-09-27T00:00:00.000
# 5    NYS-2019-0098            Janacks Point Fire  2019-09-27T00:00:00.000
# 6    NYS-2019-0097                 Dog Rock Fire  2019-09-23T00:00:00.000
# 7    NYS-2019-0096                   Giant Mt #3  2019-09-22T00:00:00.000
# 8    NYS-2019-0095      Shelving Rock Falls Fire  2019-09-22T00:00:00.000
# 9    NYS-2019-0094                Sugarloaf Fire  2019-09-20T00:00:00.000
# 10   NYS-2019-0093                  Log Bay Fire  2019-09-20T00:00:00.000
# 11   NYS-2019-0092           Giant Washbowl Fire  2019-09-18T00:00:00.000
# ...
