# %% [markdown]
# ## Seaborn and Folium Assignment
# Remember to fill in your name and your Colab link below:

# %%
# Your Name: Rishi

# %%
# Your Colab Link: https://colab.research.google.com/drive/1GXSZiSXb8epIBCh0lIys-dx2mWKpkO8s?usp=sharing

# %% [markdown]
# # Seaborn Section
#
# In this assignment, we are going to analyze several of the loaded datasets within seaborn.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1
# In this first question, you are asked to count the different cuts of diamond. Ideally, your plot would look like this. Recreate it. Bonus if you get the colour spot on, but we are just looking for the bar graph and the correct heights.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
diamonds = sns.load_dataset('diamonds')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Write your code here.

# -------------------

sns.catplot(data = diamonds, x = "cut", kind = "count")

# -------------------

# %% [markdown]
# ## Question 2
# The following dataframe shows data on the Titanic. Using seaborn methods, answer the following questions:
# *   How do the fares of the different classes compare with each other? (i.e. how much more expensive was First Class compared to Third Class?)
# *   What is the age distribution of the passengers on the Titanic?
# *   Compare the number of males to the number of females on the Titanic, separating them by class.
# *   How does the class of a passenger affect whether they survived or not?
# *   Which age range had the most survivors?

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
# Write your code and answer the questions here.

# -------------------

sns.catplot(data = titanic, x = "class", y = "fare")


# -------------------

# %%
sns.catplot(data = titanic, x = "age", kind = "count")

# %%
sns.catplot(data = titanic, x = "sex", kind = "count", hue = "class")

# %%
sns.catplot(data = titanic, x = "class", kind = "count", hue = "alive")

# %%
sns.catplot(data = titanic, x = "class", kind = "count", hue = "alive")

# %% [markdown]
# ---

# %% [markdown]
# # Folium Section
# In this section, we will be focused on the folium module, testing you on the different methods we've learned.

# %%
# !pip install geopandas

import folium
from folium import plugins
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Question 1
# We are going to graph the Wonders of the World! Using what we learned in class and a link to the github file, graph all of the Wonders of the World onto the world map and mark them with either Markers or CircleMarkers (your choice).
#
#
# Don't forget to run the import module code blocks!

# %%
wonders_link = 'https://raw.githubusercontent.com/justinabella/gecsummer2021/main/wonders_of_the_world.csv'

# Write your code here.

# -------------------




# -------------------

# %% [markdown]
# ## Question 2: Part 1
# In this assignment, we're going to have you plot the GeoJSON file of Toronto onto a map. From there, we are going to use the same file, combined with Toronto's population in 2016, and see how populated the different neighbourhoods in Toronto compare to each other. Since folium is a bit more of an intermediate topic, we have tried to do a more of a walkthrough for these questions. If you need more help, we can review GeoJSON in the next class, just let the instructors know!
#
# First we'll have you plot the GeoJSON of Toronto onto a Folium map. It should look something like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *WARNING: Do not double click the pictures above and below in your own copy. The link to these pictures are very long and causes your webpage to freeze.*

# %%
toronto_geojson = 'https://raw.githubusercontent.com/justinabella/gecsummer2021/main/toronto_neighbourhoods.geojson'

# Write your code here.

# -------------------
# We first need to define the Toronto map, zoomed in appropriately (Try a zoom level of 10)




# OPTIONAL: Using the geopandas module (gpd), turn the geojson file above into a dataframe




# Now we can add GeoJSON file to map using .add_to()
# Note: The argument that goes in the brackets should be a JSON LINK, NOT a dataframe




# Lastly, call the map of Toronto



# -------------------

# %% [markdown]
# ## Question 2: Part 2
# In this last section, we are going to plot the population of each neighbourhood on top of the GeoJSON map we plotted beforehand. As an added challenge, we will need to be cleaning the dataframe that's provided to us. After cleaning the dataframe, we should be able to easily plot the populations of the Toronto neighbourhoods.
#
# The map should ideally look something like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
toronto_neighbourhood = 'https://raw.githubusercontent.com/justinabella/gecsummer2021/main/ontario_pop_2016.CSV'

# Write your code here.

# -------------------
# Again, we need to read this file .csv into a dataframe.






# Now we need to clean the data. There columns in this dataframe that we need:
# "Geographic code", "Province or territory", "Population, 2016"
# Find a way to drop the other columns, or keep the columns we need.





# The last part of cleaning we need to do is to make sure that the Province or territory is from "Ontario"
# because we don't need the information from the other provinces and territories.
# If you need more help, check out the cleaning data exercise we did earlier this course.



# -------------------

# %%
# Write your code here.

# -------------------

# Time to redefine the Toronto map again!





# Finally, call on the Choropleth map function. Remember to use the .add_to() method.
# The important arguments that need to be defined are the geo_data, name, data, and columns.
# These are the arguments you need to figure out yourself.

# Have some of your arguments be:


#       Remember how to use the key_on attribute
#       fill_color="YlOrRd",  
#       fill_opacity=0.7,
#       line_opacity=0.2
#       legend_name="Population"
#       highlight = True 







# OPTIONAL: Layer Control





# Last but not least, call on the Toronto map variable to display the map




# -------------------
