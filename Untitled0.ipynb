# %%
x = int(input("Max num: "))
sum = 0

for i in range (0, x + 1):
  sum += i**i

print (sum)[:-10]
# Out:
# Max num: 100
# 100371115746176445351701210713361941528546861949073514542015172437236580034634746971244943788132460150776779198800002366059871900041784732217539059306483834977865973576751345853385981719448969027641921
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-3f5b91b29894> in <module>()
#       5   sum += i**i
#       6
# ----> 7 print (sum)[:-10]
#
# TypeError: 'NoneType' object is not subscriptable
